# %% [markdown]
# # Тема “Введение в математический анализ”

# %% [markdown]
# ### 1. Как соотносятся понятия “множество” и “последовательность”? (в ответе использовать слова типа: часть, целое, общее, частное, родитель, дочерний субъект и т.д.)

# %% [markdown]
# Последовательность — это упорядоченное явление, какждые элементы которой взаимо связаны и являются логическим продолжением один другого. Множество же представляет собой просто набор элементов, не связанных друг с другом логически, но похожих друг на друга.

# %% [markdown]
# ### 2. Прочитать высказывания математической логики, построить их отрицания и установить истинность.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# Для любого y принадлежащего отрезку от 0 до 1, сигнум y  равен 1.

# %% [markdown]
# #### Отрицание:

# %% [markdown]
# Для любого y принадлежащего отрезку от 0 до 1, сигнум y не равен 1.

# %% [markdown]
# #### Высказывание истино
# _____________________________________________________________________________________

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# Для любого n принадлежащего множеству натуральных чисел больше 2, существует x, y и z  принадлежащие множеству натуральных чисел, таких, что x в степени n  равно y в степени n  плюс z в степени n

# %% [markdown]
# #### Отрицание:

# %% [markdown]
# Для любого n принадлежащего множеству натуральных чисел больше 2, не существует x, y и z  принадлежащие множеству натуральных чисел, таких, что x в степени n  равно y в степени n  плюс z в степени n

# %% [markdown]
# #### Высказывание истинно
# _________________________________________________________________________

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# Для любого x принадлежащего множеству вещественных чисел существует такое X  из множества вещественных чисел, что X больше x

# %% [markdown]
# #### Отрицание:

# %% [markdown]
# Для любого x принадлежащего множеству вещественных чисел не существует таких X из множества вещественных чисел, что X больше x

# %% [markdown]
# #### Высказывание истинно
# _____________________________________________________

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# Для любого x принадлежащего множеству комплексных чисел, не существует такого y из множества комплексных чисел, где x больше y или x меньше y

# %% [markdown]
# #### Отрицание:

# %% [markdown]
# Для любого x принадлежащего множеству комплексных чисел, существует такого y из множества комплексных чисел, где x больше y или x меньше y

# %% [markdown]
# #### Высказывание ...
# _____________________________________________________

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# Для любого y принадлежащего отрезку от 0 до пи/2, существует такое эпселон больше 0, такое что синус y меньше синуса суммы y и эпселон.

# %% [markdown]
# #### Отрицание:

# %% [markdown]
# Для любого y принадлежащего отрезку от 0 до пи/2, не существует такое эпселон больше 0, такое что синус y меньше синуса суммы y и эпселон.

# %% [markdown]
# #### Высказывание истинно
# _____________________________________________

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# Для любого y принадлежащего промежутку от 0 до пи, существует такое эпселон больше 0, такое что косинус y больше косинуса суммы y и эпселон.

# %% [markdown]
# #### Отрицание:

# %% [markdown]
# Для любого y принадлежащего промежутку от 0 до пи, не существует такое эпселон больше 0, такое что косинус y больше косинуса суммы y и эпселон.

# %% [markdown]
# #### Высказывание истинно
# _______________________________

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# Существует x, такое что x не принадлежит ни одному из множеств натуральных, целых, рациональных, вещественных и комплексных чисел

# %% [markdown]
# #### Отрицание:

# %% [markdown]
# Не существует x, такое что x не принадлежит ни одному из множеств натуральных, целых, рациональных, вещественных и комплексных чисел

# %% [markdown]
# #### Высказывание ложно
# _________________________________________

# %% [markdown]
# # Тема “Множество”

# %% [markdown]
# ### 1. Даны три множества a,b и с. Необходимо выполнить все изученные виды бинарных операций над всеми комбинациями множеств.

# %% [markdown]
# ### 2. *Выполнить задание 1 на языке Python

# %%
a = {2, 4, 5, 9, 13, 25, 41}
b = {5, 7, 8, 9, 10, 11}
c = {0, -4, 8, 3, 33, 28}

# %% [markdown]
# Объединение:

# %%
a | b
# Out:
# {2, 4, 5, 7, 8, 9, 10, 11, 13, 25, 41}

# %%
b | c
# Out:
# {-4, 0, 3, 5, 7, 8, 9, 10, 11, 28, 33}

# %%
a | c
# Out:
# {-4, 0, 2, 3, 4, 5, 8, 9, 13, 25, 28, 33, 41}

# %% [markdown]
# Пересечение:

# %%
a & b
# Out:
# {5, 9}

# %%
b & c
# Out:
# {8}

# %%
a & c
# Out:
# set()

# %% [markdown]
# Раазность:

# %%
a - b
# Out:
# {2, 4, 13, 25, 41}

# %%
b - a
# Out:
# {7, 8, 10, 11}

# %%
b - c
# Out:
# {5, 7, 9, 10, 11}

# %%
c - b
# Out:
# {-4, 0, 3, 28, 33}

# %%
a - c
# Out:
# {2, 4, 5, 9, 13, 25, 41}

# %%
c - a
# Out:
# {-4, 0, 3, 8, 28, 33}

# %% [markdown]
# Симметричная разность:

# %%
a ^ b
# Out:
# {2, 4, 7, 8, 10, 11, 13, 25, 41}

# %%
b ^ c
# Out:
# {-4, 0, 3, 5, 7, 9, 10, 11, 28, 33}

# %%
a ^ c
# Out:
# {-4, 0, 2, 3, 4, 5, 8, 9, 13, 25, 28, 33, 41}

# %% [markdown]
# # Тема 3 “Последовательность”

# %% [markdown]
# в pdf файле письменно
